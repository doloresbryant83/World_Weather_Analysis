# %%
# Dependencies

import random
import numpy as np


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Perform an API call with the OpenWeatherMap.

import requests

from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=90baf05825e95a7a695d1ff7c5a11d6e

# %%
# Retrieve the following information from the API call:

# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | kultuk
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | rincon
# Processing Record 8 of Set 1 | malm
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | porto walter
# Processing Record 13 of Set 1 | shimoda
# Processing Record 14 of Set 1 | marzuq
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | zhigalovo
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | wadi musa
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | bilma
# Processing Record 26 of Set 1 | sterling
# Processing Record 27 of Set 1 | havre
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | charcas
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 32 of Set 1 | soyo
# Processing Record 33 of Set 1 | carutapera
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | kiama
# Processing Record 42 of Set 1 | enid
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | panama city
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | olafsvik
# Processing Record 49 of Set 1 | kathu
# Processing Record 50 of Set 1 | la rioja
# Processing Record 1 of Set 2 | sakakah
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | plerin
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | rabaul
# Processing Record 8 of Set 2 | asau
# Processing Record 9 of Set 2 | iwanai
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | barcelos
# Processing Record 12 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | rio grande
# Processing Record 15 of Set 2 | nagato
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | rawson
# Processing Record 20 of Set 2 | ca mau
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | kemin
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | chimbote
# Processing Record 29 of Set 2 | nabire
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | puerto suarez
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | tautira
# Processing Record 35 of Set 2 | ippy
# Processing Record 36 of Set 2 | waddan
# Processing Record 37 of Set 2 | uyemskiy
# Processing Record 38 of Set 2 | ouango
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | tartki
# City not found. Skipping...
# Processing Record 44 of Set 2 | harper
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | redlands
# Processing Record 48 of Set 2 | ballina
# Processing Record 49 of Set 2 | ambilobe
# Processing Record 50 of Set 2 | san patricio
# Processing Record 1 of Set 3 | mackay
# Processing Record 2 of Set 3 | olinda
# Processing Record 3 of Set 3 | sept-iles
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | goderich
# Processing Record 6 of Set 3 | aykhal
# Processing Record 7 of Set 3 | san jeronimo
# Processing Record 8 of Set 3 | fort nelson
# Processing Record 9 of Set 3 | msanga
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | camacupa
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | hachinohe
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | maracacume
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | komsomolskiy
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | kawalu
# Processing Record 26 of Set 3 | odweyne
# Processing Record 27 of Set 3 | malakal
# Processing Record 28 of Set 3 | kutum
# Processing Record 29 of Set 3 | rusape
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | halifax
# Processing Record 34 of Set 3 | kondinskoye
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | colares
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | kavieng
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | east bethel
# Processing Record 44 of Set 3 | buta
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | seddon
# Processing Record 49 of Set 3 | aitape
# Processing Record 50 of Set 3 | pemba
# Processing Record 1 of Set 4 | koutiala
# Processing Record 2 of Set 4 | kloulklubed
# Processing Record 3 of Set 4 | el cerrito
# Processing Record 4 of Set 4 | auki
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | kempsey
# Processing Record 8 of Set 4 | tadine
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | severodvinsk
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | kargat
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | bentiu
# Processing Record 15 of Set 4 | vostok
# Processing Record 16 of Set 4 | lata
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | warmbad
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | curup
# Processing Record 21 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 22 of Set 4 | porto belo
# Processing Record 23 of Set 4 | murbad
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | nadvoitsy
# Processing Record 26 of Set 4 | durban
# Processing Record 27 of Set 4 | berdigestyakh
# Processing Record 28 of Set 4 | mantua
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | luan
# Processing Record 31 of Set 4 | yulara
# Processing Record 32 of Set 4 | cooma
# Processing Record 33 of Set 4 | monte patria
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | pochutla
# Processing Record 36 of Set 4 | srednekolymsk
# Processing Record 37 of Set 4 | jaumave
# Processing Record 38 of Set 4 | ginda
# Processing Record 39 of Set 4 | north bend
# Processing Record 40 of Set 4 | nasaud
# Processing Record 41 of Set 4 | mersing
# Processing Record 42 of Set 4 | new smyrna beach
# Processing Record 43 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 4 | abu road
# Processing Record 46 of Set 4 | oyama
# Processing Record 47 of Set 4 | ovsyanka
# Processing Record 48 of Set 4 | atikokan
# Processing Record 49 of Set 4 | viedma
# Processing Record 50 of Set 4 | makhinjauri
# Processing Record 1 of Set 5 | chapais
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | wanning
# Processing Record 4 of Set 5 | hami
# Processing Record 5 of Set 5 | raudeberg
# Processing Record 6 of Set 5 | redencao
# Processing Record 7 of Set 5 | faya
# Processing Record 8 of Set 5 | atar
# Processing Record 9 of Set 5 | olavarria
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | half moon bay
# Processing Record 12 of Set 5 | mahebourg
# Processing Record 13 of Set 5 | la roche-sur-yon
# Processing Record 14 of Set 5 | akdepe
# Processing Record 15 of Set 5 | sherlovaya gora
# Processing Record 16 of Set 5 | qinhuangdao
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 5 | buraydah
# Processing Record 20 of Set 5 | betong
# Processing Record 21 of Set 5 | saeby
# Processing Record 22 of Set 5 | delmas
# Processing Record 23 of Set 5 | husavik
# Processing Record 24 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 5 | kunya
# Processing Record 26 of Set 5 | taoudenni
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | illapel
# Processing Record 29 of Set 5 | poso
# Processing Record 30 of Set 5 | wuwei
# Processing Record 31 of Set 5 | mehtar lam
# Processing Record 32 of Set 5 | utete
# Processing Record 33 of Set 5 | ramona
# Processing Record 34 of Set 5 | hovd
# Processing Record 35 of Set 5 | kemijarvi
# Processing Record 36 of Set 5 | tibiri
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | rudbar
# Processing Record 40 of Set 5 | vestmannaeyjar
# Processing Record 41 of Set 5 | sorong
# Processing Record 42 of Set 5 | avarua
# Processing Record 43 of Set 5 | hirara
# Processing Record 44 of Set 5 | outlook
# Processing Record 45 of Set 5 | kuala terengganu
# Processing Record 46 of Set 5 | tres marias
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | pangody
# Processing Record 49 of Set 5 | dauphin
# Processing Record 50 of Set 5 | luanda
# Processing Record 1 of Set 6 | port augusta
# Processing Record 2 of Set 6 | bucerias
# Processing Record 3 of Set 6 | riyadh
# Processing Record 4 of Set 6 | the valley
# Processing Record 5 of Set 6 | hilo
# Processing Record 6 of Set 6 | manokwari
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | lebu
# Processing Record 9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 6 | phu ly
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | dingle
# Processing Record 13 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 6 | boa vista
# Processing Record 15 of Set 6 | taltal
# Processing Record 16 of Set 6 | muros
# Processing Record 17 of Set 6 | bor
# Processing Record 18 of Set 6 | maku
# Processing Record 19 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 6 | yeppoon
# Processing Record 21 of Set 6 | bhag
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 24 of Set 6 | narsaq
# Processing Record 25 of Set 6 | saint-pierre
# Processing Record 26 of Set 6 | altamira
# Processing Record 27 of Set 6 | kovylkino
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | tromso
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | yaan
# Processing Record 32 of Set 6 | mecca
# Processing Record 33 of Set 6 | cherepovets
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | wynyard
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | adrar
# Processing Record 38 of Set 6 | eureka
# Processing Record 39 of Set 6 | kathmandu
# Processing Record 40 of Set 6 | flin flon
# Processing Record 41 of Set 6 | nishihara
# Processing Record 42 of Set 6 | bauru
# Processing Record 43 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 6 | baruun-urt
# Processing Record 45 of Set 6 | tezu
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | labytnangi
# Processing Record 48 of Set 6 | sioux lookout
# Processing Record 49 of Set 6 | zalari
# Processing Record 50 of Set 6 | santa rosa
# Processing Record 1 of Set 7 | ostrovnoy
# Processing Record 2 of Set 7 | guatire
# Processing Record 3 of Set 7 | inuvik
# Processing Record 4 of Set 7 | maloy
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | chengde
# Processing Record 9 of Set 7 | arlit
# Processing Record 10 of Set 7 | aswan
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | maun
# Processing Record 13 of Set 7 | palmas
# Processing Record 14 of Set 7 | achutupo
# Processing Record 15 of Set 7 | den helder
# Processing Record 16 of Set 7 | lavrentiya
# Processing Record 17 of Set 7 | eydhafushi
# Processing Record 18 of Set 7 | acajutla
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | trinidad
# Processing Record 21 of Set 7 | lima
# Processing Record 22 of Set 7 | general cepeda
# Processing Record 23 of Set 7 | korla
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | nizwa
# Processing Record 26 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 27 of Set 7 | sompeta
# Processing Record 28 of Set 7 | lethem
# Processing Record 29 of Set 7 | zapolyarnyy
# Processing Record 30 of Set 7 | toora-khem
# Processing Record 31 of Set 7 | saint-augustin
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | qaqortoq
# Processing Record 34 of Set 7 | lindi
# Processing Record 35 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 36 of Set 7 | barcelona
# Processing Record 37 of Set 7 | tateyama
# Processing Record 38 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 7 | san carlos de bariloche
# Processing Record 40 of Set 7 | richards bay
# Processing Record 41 of Set 7 | stornoway
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | abu dhabi
# Processing Record 44 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 7 | sandakan
# Processing Record 46 of Set 7 | poum
# Processing Record 47 of Set 7 | baiyin
# Processing Record 48 of Set 7 | chaman
# Processing Record 49 of Set 7 | goksun
# Processing Record 50 of Set 7 | chara
# Processing Record 1 of Set 8 | les cayes
# Processing Record 2 of Set 8 | viersen
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | luau
# Processing Record 5 of Set 8 | glyadyanskoye
# Processing Record 6 of Set 8 | deputatskiy
# Processing Record 7 of Set 8 | puerto escondido
# Processing Record 8 of Set 8 | airai
# Processing Record 9 of Set 8 | garmsar
# Processing Record 10 of Set 8 | vila
# Processing Record 11 of Set 8 | menongue
# Processing Record 12 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 8 | kawambwa
# Processing Record 14 of Set 8 | portsmouth
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | garowe
# Processing Record 17 of Set 8 | prescott valley
# Processing Record 18 of Set 8 | henties bay
# Processing Record 19 of Set 8 | kamariotissa
# Processing Record 20 of Set 8 | oksfjord
# Processing Record 21 of Set 8 | piskivka
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | syracuse
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | otane
# Processing Record 27 of Set 8 | shelburne
# Processing Record 28 of Set 8 | yar-sale
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | mezen
# Processing Record 31 of Set 8 | snezhnogorsk
# Processing Record 32 of Set 8 | puerto madryn
# Processing Record 33 of Set 8 | nurota
# Processing Record 34 of Set 8 | byron bay
# Processing Record 35 of Set 8 | tevaitoa
# Processing Record 36 of Set 8 | verkhnyaya inta
# Processing Record 37 of Set 8 | belmonte
# Processing Record 38 of Set 8 | grinnell
# Processing Record 39 of Set 8 | cordoba
# Processing Record 40 of Set 8 | sovetskaya gavan
# Processing Record 41 of Set 8 | bonavista
# Processing Record 42 of Set 8 | marawi
# Processing Record 43 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 8 | sao joao da barra
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | pulandian
# Processing Record 47 of Set 8 | polunochnoye
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 8 | constitucion
# Processing Record 1 of Set 9 | hasaki
# Processing Record 2 of Set 9 | mumford
# Processing Record 3 of Set 9 | san pedro
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | linhares
# Processing Record 6 of Set 9 | huarmey
# Processing Record 7 of Set 9 | launceston
# Processing Record 8 of Set 9 | brae
# Processing Record 9 of Set 9 | orange walk
# Processing Record 10 of Set 9 | maroantsetra
# Processing Record 11 of Set 9 | izberbash
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | jacareacanga
# Processing Record 14 of Set 9 | leogane
# Processing Record 15 of Set 9 | haines junction
# Processing Record 16 of Set 9 | nyurba
# Processing Record 17 of Set 9 | grand baie
# Processing Record 18 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 9 | nantucket
# Processing Record 20 of Set 9 | yerbogachen
# Processing Record 21 of Set 9 | mangrol
# Processing Record 22 of Set 9 | okha
# Processing Record 23 of Set 9 | evensk
# Processing Record 24 of Set 9 | floro
# Processing Record 25 of Set 9 | alofi
# Processing Record 26 of Set 9 | omboue
# Processing Record 27 of Set 9 | edson
# Processing Record 28 of Set 9 | praia da vitoria
# Processing Record 29 of Set 9 | enshi
# Processing Record 30 of Set 9 | teya
# Processing Record 31 of Set 9 | kushmurun
# Processing Record 32 of Set 9 | champerico
# Processing Record 33 of Set 9 | makung
# City not found. Skipping...
# Processing Record 34 of Set 9 | nagareyama
# Processing Record 35 of Set 9 | khandagayty
# Processing Record 36 of Set 9 | arman
# Processing Record 37 of Set 9 | pozo colorado
# Processing Record 38 of Set 9 | coquimbo
# Processing Record 39 of Set 9 | junagarh
# Processing Record 40 of Set 9 | xingyi
# Processing Record 41 of Set 9 | yatou
# Processing Record 42 of Set 9 | pyu
# Processing Record 43 of Set 9 | kihei
# Processing Record 44 of Set 9 | laguna
# Processing Record 45 of Set 9 | grand gaube
# Processing Record 46 of Set 9 | camana
# Processing Record 47 of Set 9 | mulchen
# Processing Record 48 of Set 9 | iwaki
# Processing Record 49 of Set 9 | jiayuguan
# Processing Record 50 of Set 9 | encruzilhada
# Processing Record 1 of Set 10 | tutoia
# Processing Record 2 of Set 10 | itamarandiba
# Processing Record 3 of Set 10 | sao jose da coroa grande
# Processing Record 4 of Set 10 | vaxjo
# Processing Record 5 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 10 | salaga
# Processing Record 7 of Set 10 | banda aceh
# Processing Record 8 of Set 10 | mimongo
# Processing Record 9 of Set 10 | polis
# Processing Record 10 of Set 10 | ashtian
# Processing Record 11 of Set 10 | shingu
# Processing Record 12 of Set 10 | isangel
# Processing Record 13 of Set 10 | nchelenge
# Processing Record 14 of Set 10 | balikpapan
# Processing Record 15 of Set 10 | trat
# Processing Record 16 of Set 10 | calatayud
# Processing Record 17 of Set 10 | chynadiyovo
# Processing Record 18 of Set 10 | pokhara
# Processing Record 19 of Set 10 | waingapu
# Processing Record 20 of Set 10 | salento
# Processing Record 21 of Set 10 | cabo san lucas
# Processing Record 22 of Set 10 | irbeyskoye
# Processing Record 23 of Set 10 | bidar
# Processing Record 24 of Set 10 | tura
# Processing Record 25 of Set 10 | taree
# Processing Record 26 of Set 10 | kruisfontein
# Processing Record 27 of Set 10 | guaruja
# Processing Record 28 of Set 10 | edgewater
# Processing Record 29 of Set 10 | chisec
# Processing Record 30 of Set 10 | kragero
# Processing Record 31 of Set 10 | bellmead
# Processing Record 32 of Set 10 | abeokuta
# Processing Record 33 of Set 10 | nautla
# Processing Record 34 of Set 10 | ilulissat
# Processing Record 35 of Set 10 | alta floresta
# Processing Record 36 of Set 10 | governador valadares
# Processing Record 37 of Set 10 | chapleau
# Processing Record 38 of Set 10 | umred
# Processing Record 39 of Set 10 | maltahohe
# Processing Record 40 of Set 10 | gevrai
# Processing Record 41 of Set 10 | flinders
# Processing Record 42 of Set 10 | kristiansund
# Processing Record 43 of Set 10 | angoche
# Processing Record 44 of Set 10 | orcopampa
# Processing Record 45 of Set 10 | palana
# Processing Record 46 of Set 10 | fenoarivo
# Processing Record 47 of Set 10 | bachaquero
# Processing Record 48 of Set 10 | dothan
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | ostersund
# Processing Record 1 of Set 11 | sinnamary
# Processing Record 2 of Set 11 | nogent-le-rotrou
# Processing Record 3 of Set 11 | coolum beach
# Processing Record 4 of Set 11 | kysyl-syr
# Processing Record 5 of Set 11 | souillac
# Processing Record 6 of Set 11 | miri
# Processing Record 7 of Set 11 | santa cruz
# Processing Record 8 of Set 11 | letterkenny
# Processing Record 9 of Set 11 | hamilton
# Processing Record 10 of Set 11 | nadadores
# Processing Record 11 of Set 11 | moose factory
# Processing Record 12 of Set 11 | luderitz
# Processing Record 13 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 11 | lugovskiy
# City not found. Skipping...
# Processing Record 15 of Set 11 | baykit
# Processing Record 16 of Set 11 | blantyre
# Processing Record 17 of Set 11 | toro
# Processing Record 18 of Set 11 | ziyang
# Processing Record 19 of Set 11 | kuala selangor
# Processing Record 20 of Set 11 | volginskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | balkanabat
# Processing Record 22 of Set 11 | emilio carranza
# Processing Record 23 of Set 11 | kavaratti
# Processing Record 24 of Set 11 | simoes
# Processing Record 25 of Set 11 | roanoke
# Processing Record 26 of Set 11 | praia
# Processing Record 27 of Set 11 | benghazi
# Processing Record 28 of Set 11 | smithers
# Processing Record 29 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 11 | darnah
# Processing Record 31 of Set 11 | kochinda
# Processing Record 32 of Set 11 | rocha
# Processing Record 33 of Set 11 | anori
# Processing Record 34 of Set 11 | sagua de tanamo
# Processing Record 35 of Set 11 | biltine
# Processing Record 36 of Set 11 | sambava
# Processing Record 37 of Set 11 | goure
# Processing Record 38 of Set 11 | baie-comeau
# Processing Record 39 of Set 11 | nata
# Processing Record 40 of Set 11 | shu
# Processing Record 41 of Set 11 | lewisporte
# Processing Record 42 of Set 11 | savannah bight
# Processing Record 43 of Set 11 | talnakh
# Processing Record 44 of Set 11 | kamphaeng phet
# Processing Record 45 of Set 11 | wucheng
# Processing Record 46 of Set 11 | bonfim
# Processing Record 47 of Set 11 | xai-xai
# Processing Record 48 of Set 11 | rong kwang
# Processing Record 49 of Set 11 | cumana
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | hurricane
# Processing Record 2 of Set 12 | quelimane
# Processing Record 3 of Set 12 | tangping
# Processing Record 4 of Set 12 | bandhi
# Processing Record 5 of Set 12 | dawlatabad
# Processing Record 6 of Set 12 | preobrazheniye
# Processing Record 7 of Set 12 | omsukchan
# Processing Record 8 of Set 12 | krasnoselkup
# Processing Record 9 of Set 12 | llallagua
# Processing Record 10 of Set 12 | ardalstangen
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | zanjan
# Processing Record 13 of Set 12 | barranca
# Processing Record 14 of Set 12 | lafayette
# Processing Record 15 of Set 12 | ambon
# Processing Record 16 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 17 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 12 | filadelfia
# Processing Record 19 of Set 12 | groningen
# Processing Record 20 of Set 12 | puerto ayacucho
# Processing Record 21 of Set 12 | buon me thuot
# City not found. Skipping...
# Processing Record 22 of Set 12 | klyuchi
# Processing Record 23 of Set 12 | tahe
# Processing Record 24 of Set 12 | kushima
# Processing Record 25 of Set 12 | la ronge
# Processing Record 26 of Set 12 | brooks
# Processing Record 27 of Set 12 | setubal
# Processing Record 28 of Set 12 | corner brook
# Processing Record 29 of Set 12 | kalianget
# Processing Record 30 of Set 12 | batagay-alyta
# Processing Record 31 of Set 12 | itirapina
# Processing Record 32 of Set 12 | padang
# Processing Record 33 of Set 12 | lugovoy
# Processing Record 34 of Set 12 | kuopio
# Processing Record 35 of Set 12 | huntington
# Processing Record 36 of Set 12 | metehara
# City not found. Skipping...
# Processing Record 37 of Set 12 | novyy urengoy
# Processing Record 38 of Set 12 | rio negro
# Processing Record 39 of Set 12 | linxia
# Processing Record 40 of Set 12 | eenhana
# Processing Record 41 of Set 12 | george
# Processing Record 42 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 43 of Set 12 | hefei
# Processing Record 44 of Set 12 | listvyanskiy
# Processing Record 45 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 12 | kibala
# Processing Record 47 of Set 12 | dawei
# Processing Record 48 of Set 12 | sao felix do xingu
# Processing Record 49 of Set 12 | chadan
# Processing Record 50 of Set 12 | sabang
# Processing Record 1 of Set 13 | matara
# Processing Record 2 of Set 13 | zhuhai
# Processing Record 3 of Set 13 | dunedin
# Processing Record 4 of Set 13 | solsona
# Processing Record 5 of Set 13 | kapenguria
# Processing Record 6 of Set 13 | tema
# Processing Record 7 of Set 13 | fukue
# Processing Record 8 of Set 13 | yataity
# Processing Record 9 of Set 13 | cockburn town
# Processing Record 10 of Set 13 | tiarei
# Processing Record 11 of Set 13 | benito juarez
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | taldan
# Processing Record 14 of Set 13 | koungou
# Processing Record 15 of Set 13 | tucumcari
# Processing Record 16 of Set 13 | karasburg
# Processing Record 17 of Set 13 | palmer
# Processing Record 18 of Set 13 | duz
# City not found. Skipping...
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | sovetskiy
# Processing Record 21 of Set 13 | tigil
# Processing Record 22 of Set 13 | salinopolis
# Processing Record 23 of Set 13 | val-david
# Processing Record 24 of Set 13 | bowen
# Processing Record 25 of Set 13 | fare
# Processing Record 26 of Set 13 | kailua
# Processing Record 27 of Set 13 | saint-joseph
# Processing Record 28 of Set 13 | elk
# Processing Record 29 of Set 13 | andradas
# Processing Record 30 of Set 13 | raub
# Processing Record 31 of Set 13 | gasa
# Processing Record 32 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 13 | clinton
# Processing Record 34 of Set 13 | camabatela
# Processing Record 35 of Set 13 | taungdwingyi
# Processing Record 36 of Set 13 | koslan
# Processing Record 37 of Set 13 | maracai
# Processing Record 38 of Set 13 | pitimbu
# Processing Record 39 of Set 13 | cururupu
# Processing Record 40 of Set 13 | villafranca de los barros
# Processing Record 41 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 42 of Set 13 | oil city
# Processing Record 43 of Set 13 | evans
# Processing Record 44 of Set 13 | albina
# Processing Record 45 of Set 13 | ashcroft
# Processing Record 46 of Set 13 | palu
# Processing Record 47 of Set 13 | springdale
# Processing Record 48 of Set 13 | ramapuram
# Processing Record 49 of Set 13 | college
# Processing Record 50 of Set 13 | houma
# Processing Record 1 of Set 14 | alta
# Processing Record 2 of Set 14 | canico
# Processing Record 3 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 4 of Set 14 | amapa
# Processing Record 5 of Set 14 | guerrero negro
# Processing Record 6 of Set 14 | broken hill
# Processing Record 7 of Set 14 | stuhr
# Processing Record 8 of Set 14 | pilao arcado
# City not found. Skipping...
# Processing Record 9 of Set 14 | preston
# Processing Record 10 of Set 14 | kjollefjord
# Processing Record 11 of Set 14 | aleksandrovka
# Processing Record 12 of Set 14 | uige
# Processing Record 13 of Set 14 | mehamn
# Processing Record 14 of Set 14 | arica
# Processing Record 15 of Set 14 | coihaique
# Processing Record 16 of Set 14 | matay
# Processing Record 17 of Set 14 | lagunas
# Processing Record 18 of Set 14 | bitlis
# Processing Record 19 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 14 | senanga
# Processing Record 22 of Set 14 | naze
# Processing Record 23 of Set 14 | tacuati
# Processing Record 24 of Set 14 | boende
# Processing Record 25 of Set 14 | kashi
# Processing Record 26 of Set 14 | tshikapa
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | kontagora
# Processing Record 29 of Set 14 | mount gambier
# Processing Record 30 of Set 14 | piney green
# Processing Record 31 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 32 of Set 14 | arua
# Processing Record 33 of Set 14 | basco
# Processing Record 34 of Set 14 | kalabo
# Processing Record 35 of Set 14 | sibolga
# Processing Record 36 of Set 14 | firovo
# Processing Record 37 of Set 14 | nemuro
# Processing Record 38 of Set 14 | asyut
# Processing Record 39 of Set 14 | castrillon
# Processing Record 40 of Set 14 | erenhot
# Processing Record 41 of Set 14 | morondava
# Processing Record 42 of Set 14 | songea
# Processing Record 43 of Set 14 | nanakuli
# Processing Record 44 of Set 14 | mocuba
# Processing Record 45 of Set 14 | grand-lahou
# Processing Record 46 of Set 14 | povolzhskiy
# Processing Record 47 of Set 14 | axim
# Processing Record 48 of Set 14 | talaya
# Processing Record 49 of Set 14 | novoagansk
# Processing Record 50 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 1 of Set 15 | calhoun
# Processing Record 2 of Set 15 | port hedland
# Processing Record 3 of Set 15 | caravelas
# Processing Record 4 of Set 15 | brekstad
# Processing Record 5 of Set 15 | marsabit
# Processing Record 6 of Set 15 | necochea
# Processing Record 7 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 8 of Set 15 | ayagoz
# Processing Record 9 of Set 15 | puerto colombia
# Processing Record 10 of Set 15 | kahului
# Processing Record 11 of Set 15 | riberalta
# Processing Record 12 of Set 15 | camacha
# Processing Record 13 of Set 15 | carman
# Processing Record 14 of Set 15 | ajdabiya
# Processing Record 15 of Set 15 | carballo
# Processing Record 16 of Set 15 | kedougou
# Processing Record 17 of Set 15 | udachnyy
# Processing Record 18 of Set 15 | lantawan
# Processing Record 19 of Set 15 | matagami
# Processing Record 20 of Set 15 | aasiaat
# Processing Record 21 of Set 15 | makakilo city
# Processing Record 22 of Set 15 | delijan
# Processing Record 23 of Set 15 | cambridge
# Processing Record 24 of Set 15 | isla aguada
# Processing Record 25 of Set 15 | sistranda
# Processing Record 26 of Set 15 | chalus
# Processing Record 27 of Set 15 | oranjestad
# Processing Record 28 of Set 15 | vangaindrano
# Processing Record 29 of Set 15 | touros
# Processing Record 30 of Set 15 | ketchikan
# Processing Record 31 of Set 15 | beatrice
# Processing Record 32 of Set 15 | maneromango
# Processing Record 33 of Set 15 | discovery bay
# Processing Record 34 of Set 15 | tirano
# Processing Record 35 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 15 | tessalit
# Processing Record 38 of Set 15 | bafra
# Processing Record 39 of Set 15 | san cristobal
# Processing Record 40 of Set 15 | abu samrah
# Processing Record 41 of Set 15 | kirkwall
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     68.74        94          94
# 1        Kultuk      RU  51.7208  103.6956     36.77        93         100
# 2       Mataura      NZ -46.1927  168.8643     50.49        89          99
# 3        Hobart      AU -42.8794  147.3294     55.27        97          75
# 4   Provideniya      RU  64.3833 -173.3000     20.98        80           6
# 5   Port Alfred      ZA -33.5906   26.8910     63.46        67          52
# 6        Rincon      US  32.2960  -81.2354     76.86        99          40
# 7          Malm      NO  64.0721   11.2172     62.44        66         100
# 8        Castro      BR -24.7911  -50.0119     61.41        90          93
# 9       Rikitea      PF -23.1203 -134.9692     72.61        70          13
#
#    Wind Speed              Description
# 0        8.79               light rain
# 1        6.91          overcast clouds
# 2        3.31          overcast clouds
# 3        1.01  light intensity drizzle
# 4        6.64                clear sky
# 5       34.72            broken clouds
# 6        3.44         scattered clouds
# 7       14.12          overcast clouds
# 8        4.16               light rain
# 9       20.20               few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
